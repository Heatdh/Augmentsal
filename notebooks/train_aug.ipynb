# %%
#!pip install wandb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 127 kB 6.1 MB/s eta 0:00:01
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.13
#     Uninstalling urllib3-1.26.13:
#       Successfully uninstalled urllib3-1.26.13
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# conda 22.9.0 requires ruamel_yaml_conda>=0.11.14, which is not installed.
# sentry-sdk 1.12.1 requires urllib3>=1.26.11; python_version >= "3.6", but you'll have urllib3 1.25.11 which is incompatible.
# ...

# %%
cd saliency
# Out:
# /data/dhahri/saliency

# %%
# !python SimpleNet/train_aug_singlecfg.py --train_im "augmented/images/Noise1" --train_maps "augmented/maps/Noise1" --name "Noise1"
# Out:
# wandb: Currently logged in as: heatdh. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.7
# wandb: Run data is saved locally in /data/dhahri/saliency/wandb/run-20221222_103407-3i0lky3d
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Noise1
# wandb: ⭐️ View project at https://wandb.ai/heatdh/Saliency
# wandb: 🚀 View run at https://wandb.ai/heatdh/Saliency/runs/3i0lky3d
# PNAS Model
# 96 96 54
# 96 270 108
# 270 540 216
# 540 1080 216
# 1080 1080 216
# 1080 1080 216
# 1080 1080 432
# 1080 2160 432
# 2160 2160 432
# 2160 2160 432
# 2160 2160 864
# 2160 4320 864
# 4320 4320 864
# 4320 4320 864
# ---------------- Reached this part --------
# cuda
# [ 0,    59] avg_loss : -0.53889, time:1.032002 minutes
# [ 0,   119] avg_loss : -0.78608, time:2.044378 minutes
# [ 0,   179] avg_loss : -0.81571, time:3.056034 minutes
# [ 0,   239] avg_loss : -0.82700, time:4.069940 minutes
# ...

# %%
# !python SimpleNet/train_aug_singlecfg.py --train_im "augmented/images/JpegCompression2" --train_maps "augmented/maps/JpegCompression2" --name "JpegCompression2" --model_val_path "model_JpegCompression2.pt"
# Out:
# wandb: Currently logged in as: heatdh. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.7
# wandb: Run data is saved locally in /data/dhahri/saliency/wandb/run-20221222_124730-1uoy0ku2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run JpegCompression2
# wandb: ⭐️ View project at https://wandb.ai/heatdh/Saliency
# wandb: 🚀 View run at https://wandb.ai/heatdh/Saliency/runs/1uoy0ku2
# PNAS Model
# 96 96 54
# 96 270 108
# 270 540 216
# 540 1080 216
# 1080 1080 216
# 1080 1080 216
# 1080 1080 432
# 1080 2160 432
# 2160 2160 432
# 2160 2160 432
# 2160 2160 864
# 2160 4320 864
# 4320 4320 864
# 4320 4320 864
# ---------------- Reached this part --------
# cuda
# [ 0,    59] avg_loss : -0.67387, time:1.052590 minutes
# [ 0,   119] avg_loss : -0.89974, time:2.058918 minutes
# [ 0,   179] avg_loss : -0.92044, time:3.065426 minutes
# [ 0,   239] avg_loss : -0.92815, time:4.071963 minutes
# ...

# %%
# !python SimpleNet/train_aug_singlecfg.py --train_im "augmented/images/JpegCompression1" --train_maps "augmented/maps/JpegCompression1" --name "JpegCompression1" --model_val_path "model_JpegCompression1.pt"

# %%
# !python SimpleNet/train_aug_singlecfg.py --train_im "augmented/images/Inversion" --train_maps "augmented/maps/Inversion" --name "Inversion" --model_val_path "model_Inversion.pt"

# %% [markdown]
# All previous runs are completed

# %%
# !python SimpleNet/train_aug_singlecfg.py --train_im "augmented/images/Contrast1" --train_maps "augmented/maps/Contrast1" --name "Contrast1" --model_val_path "model_Contrast1.pt"
# Out:
# wandb: Currently logged in as: heatdh. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.7
# wandb: Run data is saved locally in /data/dhahri/saliency/wandb/run-20221223_135851-2ko3ncxi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Contrast1
# wandb: ⭐️ View project at https://wandb.ai/heatdh/Saliency
# wandb: 🚀 View run at https://wandb.ai/heatdh/Saliency/runs/2ko3ncxi
# PNAS Model
# 96 96 54
# 96 270 108
# 270 540 216
# 540 1080 216
# 1080 1080 216
# 1080 1080 216
# 1080 1080 432
# 1080 2160 432
# 2160 2160 432
# 2160 2160 432
# 2160 2160 864
# 2160 4320 864
# 4320 4320 864
# 4320 4320 864
# ---------------- Reached this part --------
# cuda
# [ 0,    59] avg_loss : -0.48764, time:1.056692 minutes
# [ 0,   119] avg_loss : -0.80622, time:2.083283 minutes
# [ 0,   179] avg_loss : -0.82829, time:3.107665 minutes
# [ 0,   239] avg_loss : -0.84672, time:4.131433 minutes
# ...

# %%
# !python SimpleNet/train_aug_singlecfg.py --train_im "augmented/images/Contrast2" --train_maps "augmented/maps/Contrast2" --name "Contrast2" --model_val_path "model_Contrast2.pt"
